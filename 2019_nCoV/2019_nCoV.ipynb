# %% [markdown]
# + 数据源 [腾讯疫情实时追踪](https://news.qq.com/zt2020/page/feiyan.htm?from=timeline&isappinstalled=0)

# %% [markdown]
# +  导入相关模块

# %%
import time 
import json
import requests
from datetime import datetime
import pandas as pd 
import numpy as np

# %% [markdown]
# + 抓取每个城市的相关人数

# %%
def catch_cityinfo():
    url = 'https://view.inews.qq.com/g2/getOnsInfo?name=wuwei_ww_area_counts&callback=&_=%d'%int(time.time()*1000)
    city_data = requests.get(url=url).json()['data']
    city_data = json.loads(city_data)
    city_data = pd.DataFrame(city_data)
    return city_data

# %%
citydata = catch_cityinfo()
citydata.head()
# Out:
#   area city  confirm country  dead  heal  suspect
# 0   湖北   武汉     2261      中国   129    51        0
# 1   湖北   黄冈      496      中国    12     2        0
# 2   湖北   孝感      399      中国     6     0        0
# 3   湖北   荆门      191      中国     4     0        0
# 4   湖北  恩施州       66      中国     0     0        0

# %% [markdown]
# + 绘制国内疫情地图

# %%
area_data = citydata.loc[citydata["country"] == "中国"].groupby("area")["confirm"].sum().reset_index()
area_data.columns = ["area","confirm"]
area_data.head()
# Out:
#   area  confirm
# 0   上海      102
# 1   云南       55
# 2  内蒙古       16
# 3   北京      111
# 4   台湾        8

# %%
from pyecharts import options as opts
from pyecharts.charts import *
from pyecharts.globals import ThemeType

# %%
area_map = Map()
area_map .add("",[list(z) for z in zip(list(area_data["area"]), list(area_data["confirm"]))], "china",is_map_symbol_show=False)
area_map.set_global_opts(title_opts=opts.TitleOpts(title="Map-疫情地图"),visualmap_opts=opts.VisualMapOpts(max_=3000,is_piecewise=True,
                pieces=[
                 {"min": "0", "max": "10", "label": "0-10", "color": "#FFC0CB"},
                 {"min": "10", "max": "100", "label": "10-100", "color": "#F08080"},
                 {"min": "100", "max": "1000", "label": "100-1000", "color": "#FF0000"},
                 {"min": "1000", "max": "10000", "label": ">1000", "color": "#8b0000"}
             ]))
area_map.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="585a278766894ef1a33f841899edf15a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_585a278766894ef1a33f841899edf15a = echarts.init(
#                     document.getElementById('585a278766894ef1a33f841899edf15a'), 'white', {renderer: 'canvas'});
#                 var option_585a278766894ef1a33f841899edf15a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 102
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 55
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 16
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 111
#                 },
#                 {
#                     "name": "\u53f0\u6e7e",
#                     "value": 8
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 9
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 142
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 27
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 12
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 200
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 145
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 35
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 272
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 78
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 13
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 99
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 168
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 65
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 278
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 428
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 43
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 4523
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 221
#                 },
#                 {
#                     "name": "\u6fb3\u95e8",
#                     "value": 7
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 24
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 84
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 11
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 39
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 162
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 56
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 38
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": false,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Map-\u75ab\u60c5\u5730\u56fe"
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 3000,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "pieces": [
#             {
#                 "min": "0",
#                 "max": "10",
#                 "label": "0-10",
#                 "color": "#FFC0CB"
#             },
#             {
#                 "min": "10",
#                 "max": "100",
#                 "label": "10-100",
#                 "color": "#F08080"
#             },
#             {
#                 "min": "100",
#                 "max": "1000",
#                 "label": "100-1000",
#                 "color": "#FF0000"
#             },
#             {
#                 "min": "1000",
#                 "max": "10000",
#                 "label": ">1000",
#                 "color": "#8b0000"
#             }
#         ]
#     }
# };
#                 chart_585a278766894ef1a33f841899edf15a.setOption(option_585a278766894ef1a33f841899edf15a);
#         });
#     </script>

# %% [markdown]
# + 绘制世界疫情地图

# %%
world_data = citydata.groupby("country")["confirm"].sum().reset_index()
world_data.columns = ["country","confirm"]
# 这里有坑，中文地图不显示，要把国家名字替换为英文
world_name = pd.read_excel("世界各国中英文对照.xlsx")
world_data_ = pd.merge(world_data,world_name,left_on ="country",right_on = "中文",how="inner")
world_data_.head()
# Out:
#   country  confirm         英文    中文
# 0      中国     7488      China    中国
# 1     加拿大        2     Canada   加拿大
# 2     尼泊尔        1      Nepal   尼泊尔
# 3      德国        4    Germany    德国
# 4    斯里兰卡        1  Sri Lanka  斯里兰卡

# %%
world_map = Map()
world_map.add("",[list(z) for z in zip(list(world_data_["英文"]), list(world_data_["confirm"]))], "world",is_map_symbol_show=False)
world_map.set_global_opts(title_opts=opts.TitleOpts(title="2019_nCoV-世界疫情地图"),visualmap_opts=opts.VisualMapOpts(max_=5),legend_opts=opts.LegendOpts(is_show=False))
world_map.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
world_map.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#         <div id="8e0107305ee24d098b8e89542be87fd3" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_8e0107305ee24d098b8e89542be87fd3 = echarts.init(
#                     document.getElementById('8e0107305ee24d098b8e89542be87fd3'), 'white', {renderer: 'canvas'});
#                 var option_8e0107305ee24d098b8e89542be87fd3 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "world",
#             "data": [
#                 {
#                     "name": "China",
#                     "value": 7488
#                 },
#                 {
#                     "name": "Canada",
#                     "value": 2
#                 },
#                 {
#                     "name": "Nepal",
#                     "value": 1
#                 },
#                 {
#                     "name": "Germany",
#                     "value": 4
#                 },
#                 {
#                     "name": "Sri Lanka",
#                     "value": 1
#                 },
#                 {
#                     "name": "Singapore",
#                     "value": 10
#                 },
#                 {
#                     "name": "Japan",
#                     "value": 8
#                 },
#                 {
#                     "name": "France",
#                     "value": 5
#                 },
#                 {
#                     "name": "Thailand",
#                     "value": 14
#                 },
#                 {
#                     "name": "Australia",
#                     "value": 7
#                 },
#                 {
#                     "name": "U.S.A",
#                     "value": 5
#                 },
#                 {
#                     "name": "Finland",
#                     "value": 1
#                 },
#                 {
#                     "name": "Vietnam",
#                     "value": 2
#                 },
#                 {
#                     "name": "Korea(republic of)",
#                     "value": 4
#                 },
#                 {
#                     "name": "Malaysia",
#                     "value": 7
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": false,
#             "emphasis": {},
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": false
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "2019_nCoV-\u4e16\u754c\u75ab\u60c5\u5730\u56fe"
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 5,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true
#     }
# };
#                 chart_8e0107305ee24d098b8e89542be87fd3.setOption(option_8e0107305ee24d098b8e89542be87fd3);
#         });
#     </script>

# %% [markdown]
# + 抓取每日确诊和死亡数据

# %%
def catch_daily():
    url = 'https://view.inews.qq.com/g2/getOnsInfo?name=wuwei_ww_cn_day_counts&callback=&_=%d'%int(time.time()*1000)
    data = json.loads(requests.get(url=url).json()['data'])
    data.sort(key=lambda x:x['date'])
    return data

# %%
daily_data = pd.DataFrame(catch_daily())
daily_data.to_excel("daily_data.xlsx")
daily_data.head()
# Out:
#   confirm   date dead heal suspect
# 0      41  01.13    1    0       0
# 1      41  01.14    1    0       0
# 2      41  01.15    2    5       0
# 3      45  01.16    2    8       0
# 4      62  01.17    2   12       0

# %%
line = Line()
line.add_xaxis(list(daily_data["date"]))
line.add_yaxis("heal",list(daily_data["heal"]))
line.add_yaxis("dead", list(daily_data["dead"]))
line.set_global_opts(title_opts=opts.TitleOpts(title="Line-治愈与死亡趋势"))
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="2c1f16dc2dc84862a6d6cb687a5e5a24" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2c1f16dc2dc84862a6d6cb687a5e5a24 = echarts.init(
#                     document.getElementById('2c1f16dc2dc84862a6d6cb687a5e5a24'), 'white', {renderer: 'canvas'});
#                 var option_2c1f16dc2dc84862a6d6cb687a5e5a24 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "heal",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "01.13",
#                     "0"
#                 ],
#                 [
#                     "01.14",
#                     "0"
#                 ],
#                 [
#                     "01.15",
#                     "5"
#                 ],
#                 [
#                     "01.16",
#                     "8"
#                 ],
#                 [
#                     "01.17",
#                     "12"
#                 ],
#                 [
#                     "01.18",
#                     "17"
#                 ],
#                 [
#                     "01.19",
#                     "18"
#                 ],
#                 [
#                     "01.20",
#                     "25"
#                 ],
#                 [
#                     "01.21",
#                     "25"
#                 ],
#                 [
#                     "01.22",
#                     "25"
#                 ],
#                 [
#                     "01.23",
#                     "34"
#                 ],
#                 [
#                     "01.24",
#                     "38"
#                 ],
#                 [
#                     "01.25",
#                     "49"
#                 ],
#                 [
#                     "01.26",
#                     "51"
#                 ],
#                 [
#                     "01.27",
#                     "60"
#                 ],
#                 [
#                     "01.28",
#                     "103"
#                 ],
#                 [
#                     "01.29",
#                     "124"
#                 ],
#                 [
#                     "01.30",
#                     "124"
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         {
#             "type": "line",
#             "name": "dead",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "01.13",
#                     "1"
#                 ],
#                 [
#                     "01.14",
#                     "1"
#                 ],
#                 [
#                     "01.15",
#                     "2"
#                 ],
#                 [
#                     "01.16",
#                     "2"
#                 ],
#                 [
#                     "01.17",
#                     "2"
#                 ],
#                 [
#                     "01.18",
#                     "3"
#                 ],
#                 [
#                     "01.19",
#                     "4"
#                 ],
#                 [
#                     "01.20",
#                     "6"
#                 ],
#                 [
#                     "01.21",
#                     "9"
#                 ],
#                 [
#                     "01.22",
#                     "17"
#                 ],
#                 [
#                     "01.23",
#                     "25"
#                 ],
#                 [
#                     "01.24",
#                     "41"
#                 ],
#                 [
#                     "01.25",
#                     "56"
#                 ],
#                 [
#                     "01.26",
#                     "80"
#                 ],
#                 [
#                     "01.27",
#                     "106"
#                 ],
#                 [
#                     "01.28",
#                     "132"
#                 ],
#                 [
#                     "01.29",
#                     "170"
#                 ],
#                 [
#                     "01.30",
#                     "170"
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "heal",
#                 "dead"
#             ],
#             "selected": {
#                 "heal": true,
#                 "dead": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "01.13",
#                 "01.14",
#                 "01.15",
#                 "01.16",
#                 "01.17",
#                 "01.18",
#                 "01.19",
#                 "01.20",
#                 "01.21",
#                 "01.22",
#                 "01.23",
#                 "01.24",
#                 "01.25",
#                 "01.26",
#                 "01.27",
#                 "01.28",
#                 "01.29",
#                 "01.30"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }

# %%
def bar() -> Bar:
    c = (
        Bar({"theme": ThemeType.MACARONS})
        .add_xaxis(list(daily_data["date"]))
        .add_yaxis("confirm", list(daily_data["confirm"]))
        .add_yaxis("suspect", list(daily_data["suspect"]))
        .set_global_opts(
            title_opts={"text": "Bar-患病人数增长趋势"}
        )
    )
    return c
bar().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'macarons':'https://assets.pyecharts.org/assets/themes/macarons'
#         }
#     });
# </script>
#
#         <div id="e3bf1c39d561425298de037aee49301c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'macarons'], function(echarts) {
#                 var chart_e3bf1c39d561425298de037aee49301c = echarts.init(
#                     document.getElementById('e3bf1c39d561425298de037aee49301c'), 'macarons', {renderer: 'canvas'});
#                 var option_e3bf1c39d561425298de037aee49301c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "confirm",
#             "data": [
#                 "41",
#                 "41",
#                 "41",
#                 "45",
#                 "62",
#                 "198",
#                 "275",
#                 "291",
#                 "440",
#                 "571",
#                 "830",
#                 "1287",
#                 "1975",
#                 "2744",
#                 "4515",
#                 "5974",
#                 "7711",
#                 "7742"
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "suspect",
#             "data": [
#                 "0",
#                 "0",
#                 "0",
#                 "0",
#                 "0",
#                 "0",
#                 "0",
#                 "54",
#                 "37",
#                 "393",
#                 "1072",
#                 "1965",
#                 "2684",
#                 " 5794",
#                 "6973",
#                 "9239",
#                 "12167",
#                 "12167"
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "confirm",
#                 "suspect"
#             ],
#             "selected": {
#                 "confirm": true,
#                 "suspect": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "01.13",
#                 "01.14",
#                 "01.15",
#                 "01.16",
#                 "01.17",
#                 "01.18",
#                 "01.19",
#                 "01.20",
#                 "01.21",
#                 "01.22",
#                 "01.23",
#                 "01.24",
#                 "01.25",
#                 "01.26",
#                 "01.27",
#                 "01.28",
#                 "01.29",
#                 "01.30"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": {
#         "text": "Bar-\u60a3\u75c5\u4eba\u6570\u589e\u957f\u8d8b\u52bf"
#     }
# };
#                 chart_e3bf1c39d561425298de037aee49301c.setOption(option_e3bf1c39d561425298de037aee49301c);
#         });
#     </script>
